# %%
import jupyter_black

jupyter_black.load()

# %%
# Importing Libraries

import numpy as np
import astropy
import photutils
import ccdproc
from ccdproc import CCDData, combiner
from astropy import units as u
import astropy.io.fits as fits
from astropy.io import ascii

from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from photutils.centroids import centroid_com, centroid_1dg, centroid_2dg
from photutils.aperture import CircularAperture
from photutils.aperture import aperture_photometry
from photutils.background import Background2D
from photutils.background import MedianBackground
from photutils.detection import DAOStarFinder
from photutils.segmentation import detect_sources, deblend_sources, SourceCatalog
from scipy.ndimage import shift
import astroalign as aa
import gc

from astropy.coordinates import SkyCoord
# Out:
# /Users/alec/honours-env/.venv/lib/python3.11/site-packages/google_crc32c/__init__.py:29: RuntimeWarning: As the c extension couldn't be imported, `google-crc32c` is using a pure python implementation that is significantly slower. If possible, please configure a c build environment and compile the extension
#   warnings.warn(_SLOW_CRC32C_WARNING, RuntimeWarning)

# %%
# Path for aligned images
path = "Aligned_S50_faeae72a_20260321_debayer/NGC_2175_sub/"
r_images = ccdproc.ImageFileCollection(path, glob_include="*r.fit")
g_images = ccdproc.ImageFileCollection(path, glob_include="*g.fit")
b_images = ccdproc.ImageFileCollection(path, glob_include="*b.fit")

# %%
# Reading and storing scientific images

r_scim = []
r_names = []
g_scim = []
g_names = []
b_scim = []
b_names = []
for fn in r_images.files:
    r_scim.append(
        CCDData.read(path + fn)
    )  # Reading data and adding the image to scim list
    r_names.append(fn)

del r_images
gc.collect()

for fn in g_images.files:
    g_scim.append(
        CCDData.read(path + fn)
    )  # Reading data and adding the image to scim list
    g_names.append(fn)

del g_images
gc.collect()

for fn in b_images.files:
    b_scim.append(
        CCDData.read(path + fn)
    )  # Reading data and adding the image to scim list
    b_names.append(fn)

del b_images
gc.collect()
# Out:
# 20

# %%
r_sci_median = ccdproc.combine(
    r_scim, method="median", dtype=np.float32, minmax_clip=True, minmax_clip_min=-500, header_strategy='first'
)
b_sci_median = ccdproc.combine(
    b_scim, method="median", dtype=np.float32, minmax_clip=True, minmax_clip_min=-500, header_strategy='first'
)
g_sci_median = ccdproc.combine(
    g_scim, method="median", dtype=np.float32, minmax_clip=True, minmax_clip_min=-500, header_strategy='first'
)
r_sci_median.write("r_median.fits", overwrite=True)
b_sci_median.write("b_median.fits", overwrite=True)
g_sci_median.write("g_median.fits", overwrite=True)

del r_scim, b_scim, g_scim, r_sci_median, b_sci_median, g_sci_median
gc.collect()
# Out:
# INFO:astropy:splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes.
# INFO: splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes. [ccdproc.combiner]
# INFO:astropy:splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes.
# INFO: splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes. [ccdproc.combiner]
# INFO:astropy:splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes.
# INFO: splitting each image into 2 chunks to limit memory usage to 16000000000.0 bytes. [ccdproc.combiner]
# 0
